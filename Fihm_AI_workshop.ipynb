# %% [markdown]
# ![images (3).png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ---
#
#
#
#
#
#
#
#
# **Fihm AI Workshop**
#
#
#
#
# ---
#
#
#
#
# ---

# %% [markdown]
# # First : Define Fully-Connected Neural Network Model

# %% [markdown]
# ### Task 1: Import libraries and modules

# %% [markdown]
# We begin with some imports
#
# Things to consider
#
# *   which typye of layer do we need here
# *   List item

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Input, Dense # Dropout, Activation, Flatten, Convolution2D, MaxPooling2D
from keras import utils

# %% [markdown]
# ### Task 2: Load image data (MNIST) from Keras.

# %% [markdown]
# We will strat with MNIST dataset.
#
# The Keras library alreaady includes MNIST.

# %%
from keras.datasets import mnist

# Load pre-shuffled MNIST data into train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# What is the shape of the training data?
#
# What is the shape of the test data?
#
# What is the shape of the training labels?

# %%
y_train[50]

# %%
x_train[50].shape

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[50])
plt.axis('off')

# %%
x_train=x_train.reshape(60000,784)

# %%
x_train.shape

# %% [markdown]
# ### Task 3: Preprocess input data

# %% [markdown]
# We will change the shape of the training and testing data to be be sutable for *our* model

# %%
x_train = x_train.reshape(x_train.shape[0], 28*28)
x_test = x_test.reshape(x_test.shape[0],28*28)

# %% [markdown]
# What is the shape now?

# %%
print(x_train.shape)

# %% [markdown]
# In order to do preprocessing step we need to check some values (max, min)

# %%
print(x_train.max())

# %% [markdown]
# We will convert:
# 1.   The data type to float32

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %% [markdown]
# 2.   normalize our data values to the range [0, 1].

# %%
x_train /= 255
x_test /= 255

# %% [markdown]
# What about the y_train?

# %%
print(y_train.shape)

# %% [markdown]
# We will change the shape of class labels to be be sutable for *our* model
# *   1-D class arrays to 10-D class matrices

# %%
y_train = utils.to_categorical(y_train, 10)
y_test = utils.to_categorical(y_test, 10)

# %% [markdown]
# ### Task 4:  Model architecture (Fully-Connected Neural Network)

# %% [markdown]
# We will declare a sequential model and call it model

# %%
	model = Sequential()

# %% [markdown]
# We will first add the input layer
#
# 1.   List item
# 2.   List item

# %%
model.add(Input(shape=(784,)))

# %% [markdown]
# We will add first hidden layer
#
#
# *   Activation can be within the dense layer or can be a separate *layer*
# *   Consider other types of activation function

# %%
model.add(Dense(50, activation='relu'))

# %% [markdown]
# Add hidden layer with any number of nodes
#
# *   \# indicates comment line, means it will not be executed

# %%
model.add(Dense(50, activation='relu'))
# model.add(Dense(500, activation='relu'))
# model.add(Dense(500, activation='relu'))

# %% [markdown]
# We will add last  layer
#
#
# *   Activation here should be softmax, why?
# *   Why the number of nodes is 10?

# %%
model.add(Dense(10, activation='softmax'))

# %%
model.summary()

# %% [markdown]
# The entire model architecture:

# %%
model = Sequential()
model.add(Input(shape=(784,))) # input layer
model.add(Dense(500, activation='relu')) # 1st hidden layer
model.add(Dense(500, activation='relu')) # 2nd hidden layer

model.add(Dense(10, activation='softmax')) # last layer
model.summary()

# %% [markdown]
# ### Task 5: Compile our model

# %% [markdown]
# We need to identify or declare:
#
# 1.  The loss function
# 2.  The optimizer (SGD, Adam, etc.).
# 3.  The metrics to be evaluated by the model during training and testing

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ### Step 5: Fit our model

# %% [markdown]
# We will fit our model in the training data, we need to identify or declare:
#
# 1.  The training data (x_train)
# 2.  The training class labels (y_train)
# 3.  The batch size
# 4.  The number of epochs

# %%
model.fit(x_train, y_train, batch_size=32, epochs=5)

# %% [markdown]
# Congratulation, we are done!!!

# %% [markdown]
# ### Step 6: Evaluate the model on test data

# %% [markdown]
# We will evaluate our model on the test data

# %%
model.evaluate(x_test, y_test)

# %% [markdown]
# # Second : Define Convolutional Neural Network Model

# %% [markdown]
# ![Dgy6hBvOvAWofkrDM8BclOU3E3C2hqb25qBb.png](data:image/png;base64,...)

# %% [markdown]
# ![dobVrh3SGyqQraM2ogi-P3VK2K-LFsBm7RLO.png](data:image/png;base64,...)

# %% [markdown]
# ![Htskzls1pGp98-X2mHmVy9tCj0cYXkiCrQ4t.gif](data:image/gif;base64,...)

# %% [markdown]
# ![Gjxh-aApWTzIRI1UNmGnNLrk8OKsQaf2tlDu.png](data:image/png;base64,...)

# %% [markdown]
# ![gb08-2i83P5wPzs3SL-vosNb6Iur5kb5ZH43.gif](data:image/gif;base64,...)

# %% [markdown]
# We will build CNN architecture, SAME AS BEFORE, but will change:
#
# 1. Data shape
# 2. Input shape
# 3. Architecture

# %%
from keras.models import Sequential
from keras.layers import Input, Dense , Dropout, Activation, Flatten
from keras.layers import Conv2D , MaxPooling2D
from keras import utils
from keras.datasets import mnist

# %%
# Load MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Preprocess steps
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# class labels
y_train = utils.to_categorical(y_train, 10)
y_test = utils.to_categorical(y_test, 10)

# %%
# CNN model architecture
model = Sequential()
model.add(Conv2D (32, 3, activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D (32, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()

# %%
# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Fit the model
model.fit(x_train, y_train, batch_size=32, epochs=20)

# %%
# Evaluate the model on test data and save the result in score
score = model.evaluate(x_test, y_test)

# %% [markdown]
# Ali Alqahtani
#
# Founding member at [Fihm](https://fihm.ai/)
#
# Twitter: [@alialqahtani14](https://twitter.com/alialqahtani14)
